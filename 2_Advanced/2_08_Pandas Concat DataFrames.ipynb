# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/2_08_Pandas Concat DataFrames.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## 🟩 Concat Job Postings (2.8.1)

# %%
lower_income = df[df['salary_year_avg'] < 100000]
lower_income
# Out:
#               job_title_short  \
# 109              Data Analyst
# 180              Data Analyst
# 380             Data Engineer
# 388             Data Engineer
# 520          Business Analyst
# ...                       ...
# 784102          Data Engineer
# 784423           Data Analyst
# 784882           Data Analyst
# 785132  Senior Data Scientist
# 785395          Data Engineer
#
#                                                 job_title  \
# 109                 Senior Supply Chain Analytics Analyst
# 180                                      Data Analyst III
# 380                               Snaplogic Data Engineer
# 388                                         Data Engineer
# 520                                      Power BI Analyst
# ...                                                   ...
# 784102                Data Engineer III- Data Engineering
# 784423                                 Sales Data Analyst
# 784882               Merchandising Analyst (Data Analyst)
# ...

# %%
higher_income = df[df['salary_year_avg'] >= 100000]
higher_income
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 116     Data Scientist                                     Data Scientist
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
allIncomes = pd.concat([higher_income, lower_income], ignore_index=True)
allIncomes
# Out:
#              job_title_short  \
# 0             Data Scientist
# 1              Data Engineer
# 2              Data Engineer
# 3             Data Scientist
# 4             Data Scientist
# ...                      ...
# 21998          Data Engineer
# 21999           Data Analyst
# 22000           Data Analyst
# 22001  Senior Data Scientist
# 22002          Data Engineer
#
#                                                job_title  \
# 0                                    CRM Data Specialist
# 1                                          Data Engineer
# 2                Remote - Data Engineer - Permanent - W2
# 3                Data Scientist, Risk Data Mining - USDS
# 4                                         Data Scientist
# ...                                                  ...
# 21998                Data Engineer III- Data Engineering
# 21999                                 Sales Data Analyst
# 22000               Merchandising Analyst (Data Analyst)
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Concat Monthly Postings (2.8.2)

# %%
monthly_df = df.copy()
monthly_df['month_posted'] = monthly_df['job_posted_date'].dt.strftime('%b')
month_list = monthly_df['month_posted'].unique()

monthly_df_dict = {month: monthly_df[monthly_df['month_posted'] == month] for month in month_list}

first_quarter_df = pd.concat([monthly_df_dict['Jan'], monthly_df_dict['Feb'], monthly_df_dict['Mar']], ignore_index=True)
first_quarter_df['month_posted'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='month_posted'>

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Concat Job Types (2.8.3)

# %%
job_type_df = df.copy()

jobs = job_type_df['job_title_short'].unique()

job_type_dict = {job: df[df['job_title_short'] == job] for job in jobs}

data_job_df = pd.concat([job_type_dict['Senior Data Engineer'], job_type_dict['Data Analyst'], job_type_dict['Data Engineer'], job_type_dict['Data Scientist'], job_type_dict['Senior Data Analyst'], job_type_dict['Senior Data Scientist']], ignore_index=True)

data_job_df['job_title_short'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_title_short'>

# %% [markdown]
# ---
