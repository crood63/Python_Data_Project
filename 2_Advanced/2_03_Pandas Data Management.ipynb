# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/2_03_Pandas Data Management.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## 🟩 Drop Missing Values (2.3.1)

# %%
df_drop_nan = df.copy()
df_drop_nan = df_drop_nan.dropna(subset=['salary_rate', 'job_skills', 'job_location', 'job_schedule_type', 'job_via'])
df_drop_nan.count()
# Out:
# job_title_short          29346
# job_title                29346
# job_location             29346
# job_via                  29346
# job_schedule_type        29346
# job_work_from_home       29346
# search_location          29346
# job_posted_date          29346
# job_no_degree_mention    29346
# job_health_insurance     29346
# job_country              29346
# salary_rate              29346
# salary_year_avg          19908
# salary_hour_avg           9097
# company_name             29346
# job_skills               29346
# job_type_skills          29346
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Random Sample of DataFrame (2.3.2)

# %%
df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Fill Missing Salaries (2.3.3)

# %%
df_salary_fill = df_drop_nan.copy()
yearly_salary_med = df_salary_fill['salary_year_avg'].median()
hourly_salary_med = df_salary_fill['salary_hour_avg'].median()

df_salary_fill['salary_year_avg'] = df_salary_fill['salary_year_avg'].fillna(yearly_salary_med)
df_salary_fill['salary_hour_avg'] = df_salary_fill['salary_hour_avg'].fillna(hourly_salary_med)

df_salary_fill
# Out:
#              job_title_short  \
# 28            Data Scientist
# 51      Senior Data Engineer
# 77             Data Engineer
# 92             Data Engineer
# 100           Data Scientist
# ...                      ...
# 785563        Data Scientist
# 785624         Data Engineer
# 785648        Data Scientist
# 785682        Data Scientist
# 785692        Data Scientist
#
#                                                 job_title  \
# 28                                    CRM Data Specialist
# 51                                   Senior Data Engineer
# 77                                          Data Engineer
# 92                Remote - Data Engineer - Permanent - W2
# 100               Data Scientist, Risk Data Mining - USDS
# ...                                                   ...
# 785563  Data Scientist I/II (Model Risk Management & M...
# 785624                   Data Analytics Engineer (Hybrid)
# 785648  Director Data Scientist - Commercial Platforms...
# ...

# %% [markdown]
# ---
