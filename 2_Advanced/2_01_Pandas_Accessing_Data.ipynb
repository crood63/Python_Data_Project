# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/2_01_Pandas Accessing Data.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## 🟩 Select First 5 Rows with .iloc() (2.1.1)

# %%
df.iloc[:5]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Get Rows and Columns with .loc() (2.1.2)

# %%
df.loc[:5, 'salary_rate':'salary_hour_avg']
# Out:
#   salary_rate  salary_year_avg  salary_hour_avg
# 0        None              NaN              NaN
# 1        None              NaN              NaN
# 2        None              NaN              NaN
# 3        None              NaN              NaN
# 4        None              NaN              NaN
# 5        None              NaN              NaN

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 First 15 Rows in US (2.1.3)

# %%
df[df['job_country'] == 'United States'].loc[10:30]
# Out:
#          job_title_short                                          job_title  \
# 11         Data Engineer                                      Data Engineer
# 13  Senior Data Engineer                               Senior Data Engineer
# 17        Data Scientist                             Data Science Team Lead
# 26         Data Engineer                                      Data Engineer
# 27         Data Engineer  Principal Data Engineer (Lead), Knowledge Grap...
# 30  Senior Data Engineer     Senior Data Engineer (Work from home Eligible)
#
#                           job_location  \
# 11  Colorado Springs, CO   (+3 others)
# 13                        New York, NY
# 17                          Laurel, MD
# 26                       United States
# 27                   San Francisco, CA
# 30                      Wilmington, DE
#
#                                               job_via job_schedule_type  \
# 11                                       via The Muse         Full-time
# 13                                       via LinkedIn         Full-time
# 17  via APL Careers - Johns Hopkins University App...         Full-time
# 26                                       via LinkedIn         Full-time
# 27                                       via LinkedIn         Full-time
# 30                                      via WDHN Jobs         Full-time
#
#     job_work_from_home       search_location     job_posted_date  \
# 11               False  Texas, United States 2023-11-03 13:06:51
# 13               False  Texas, United States 2023-11-15 13:08:52
# 17               False               Georgia 2023-06-13 13:25:17
# 26               False               Georgia 2023-09-15 13:56:18
# 27               False               Georgia 2023-02-18 13:31:24
# 30               False  Texas, United States 2023-03-29 13:32:03
#
#     job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 11                  False                  True  United States        None
# 13                   True                  True  United States        None
# 17                  False                  True  United States        None
# 26                   True                 False  United States        None
# 27                  False                 False  United States        None
# 30                  False                  True  United States        None
#
#     salary_year_avg  salary_hour_avg  \
# 11              NaN              NaN
# 13              NaN              NaN
# 17              NaN              NaN
# 26              NaN              NaN
# 27              NaN              NaN
# 30              NaN              NaN
#
#                                 company_name  \
# 11                                   Philips
# 13                                     Nayya
# 17  Johns Hopkins Applied Physics Laboratory
# 26               Infinite Computer Solutions
# 27                                Altos Labs
# 30                               Capital One
#
#                                            job_skills  \
# 11                                 ['python', 'qlik']
# 13  ['python', 'sql', 'go', 'ruby', 'ruby', 'javas...
# 17                             ['go', 'apl', 'excel']
# 26                                               None
# 27                            ['python', 'r', 'java']
# 30  ['scala', 'python', 'nosql', 'mongo', 'shell',...
#
#                                       job_type_skills  job_posted_month
# 11  {'analyst_tools': ['qlik'], 'programming': ['p...                11
# 13  {'cloud': ['aws'], 'other': ['terraform'], 'pr...                11
# 17  {'analyst_tools': ['excel'], 'programming': ['...                 6
# 26                                               None                 9
# 27           {'programming': ['python', 'r', 'java']}                 2
# 30  {'cloud': ['redshift', 'snowflake', 'aws', 'az...                 3

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Filter by Date (2.1.4)

# %%
df['job_posted_month'] = df['job_posted_date'].dt.month
df[df['job_posted_month'] == 6].loc[:100]
# Out:
#           job_title_short                                          job_title  \
# 0    Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 8        Business Analyst           Technology & Operations Business Analyst
# 16          Data Engineer                                  Big Data Engineer
# 17         Data Scientist                             Data Science Team Lead
# 24         Data Scientist                      Data Scientist (DataLab Team)
# 25    Senior Data Analyst                  Senior Officer, Data Analyst, GTO
# 33          Data Engineer                                      Data Engineer
# 51   Senior Data Engineer                               Senior Data Engineer
# 65          Data Engineer             System Reliability Engineer (Big Data)
# 70  Senior Data Scientist            Sr Principal Data Scientist/ML Engineer
# 73           Data Analyst        Entry level / Systems Data Analyst (Remote)
# 77          Data Engineer                                      Data Engineer
# 93           Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 96          Data Engineer                                      Data Engineer
#
#                  job_location  \
# 0               Watertown, CT
# 8         Copenhagen, Denmark
# 16   Pune, Maharashtra, India
# 17                 Laurel, MD
# 24                   Anywhere
# 25                  Singapore
# 33  County Westmeath, Ireland
# 51                   Anywhere
# 65                   Missouri
# 70            Little Rock, AR
# 73                   Anywhere
# 77              Arlington, VA
# 93                   Anywhere
# 96               Torrance, CA
#
#                                               job_via job_schedule_type  \
# 0                                     via Work Nearby         Full-time
# 8                                     via Trabajo.org         Full-time
# 16                                       via LinkedIn         Full-time
# 17  via APL Careers - Johns Hopkins University App...         Full-time
# 24                                       via LinkedIn         Full-time
# 25                                via BeBee Singapore         Full-time
# 33                                         via Indeed         Full-time
# 51                                       via LinkedIn        Contractor
# 65                     via SmartRecruiters Job Search         Full-time
# 70                                    via Trabajo.org         Full-time
# 73                                       via LinkedIn        Contractor
# 77                                       via LinkedIn         Full-time
# 93                                       via LinkedIn         Full-time
# 96                                       via LinkedIn         Full-time
#
#     job_work_from_home            search_location     job_posted_date  \
# 0                False       Texas, United States 2023-06-16 13:44:15
# 8                False                    Denmark 2023-06-05 13:44:34
# 16               False                      India 2023-06-15 13:28:03
# 17               False                    Georgia 2023-06-13 13:25:17
# 24                True                     Serbia 2023-06-27 13:46:46
# 25               False                  Singapore 2023-06-23 13:56:10
# 33               False                    Ireland 2023-06-26 13:54:47
# 51                True    Illinois, United States 2023-06-21 13:09:39
# 65               False  California, United States 2023-06-16 13:43:03
# 70               False                      Sudan 2023-06-17 14:10:13
# 73                True    Illinois, United States 2023-06-16 13:18:22
# 77               False                      Sudan 2023-06-26 14:22:54
# 93                True    New York, United States 2023-06-10 13:00:05
# 96               False                      Sudan 2023-06-15 14:03:55
#
#     job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                   False                 False  United States        None
# 8                   False                 False        Denmark        None
# 16                  False                 False          India        None
# 17                  False                  True  United States        None
# 24                  False                 False         Serbia        None
# 25                   True                 False      Singapore        None
# 33                  False                 False        Ireland        None
# 51                  False                 False  United States        hour
# 65                   True                 False  United States        None
# 70                  False                  True          Sudan        None
# 73                   True                  True  United States        None
# 77                  False                 False          Sudan        year
# 93                  False                 False  United States        None
# 96                  False                 False          Sudan        None
#
#     salary_year_avg  salary_hour_avg  \
# 0               NaN              NaN
# 8               NaN              NaN
# 16              NaN              NaN
# 17              NaN              NaN
# 24              NaN              NaN
# 25              NaN              NaN
# 33              NaN              NaN
# 51              NaN             72.5
# 65              NaN              NaN
# 70              NaN              NaN
# 73              NaN              NaN
# 77         140000.0              NaN
# 93              NaN              NaN
# 96              NaN              NaN
#
#                                 company_name  \
# 0                       Boehringer Ingelheim
# 8                                     Hempel
# 16                     Hexaware Technologies
# 17  Johns Hopkins Applied Physics Laboratory
# 24                                   Semrush
# 25                      United Overseas Bank
# 33                         Eolas Recruitment
# 51                          Aditi Consulting
# 65                      Fulcrum Digital Inc.
# 70                                    Oracle
# 73                                Soft Magic
# 77                                Intelletec
# 93   Get It Recruit - Information Technology
# 96                           King's Hawaiian
#
#                                            job_skills  \
# 0                                                None
# 8                 ['excel', 'powerpoint', 'power bi']
# 16  ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 17                             ['go', 'apl', 'excel']
# 24                                         ['python']
# 25                                            ['sql']
# 33  ['sql', 'python', 'r', 'azure', 'databricks', ...
# 51   ['python', 'java', 'aws', 'databricks', 'spark']
# 65  ['sql', 'hadoop', 'spark', 'jenkins', 'chef', ...
# 70  ['python', 'go', 'oracle', 'scikit-learn', 'te...
# 73         ['word', 'excel', 'powerpoint', 'outlook']
# 77  ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 93  ['oracle', 'azure', 'power bi', 'excel', 'word...
# 96  ['sql', 'r', 'python', 'sql server', 'azure', ...
#
#                                       job_type_skills  job_posted_month
# 0                                                None                 6
# 8   {'analyst_tools': ['excel', 'powerpoint', 'pow...                 6
# 16  {'cloud': ['databricks', 'azure'], 'databases'...                 6
# 17  {'analyst_tools': ['excel'], 'programming': ['...                 6
# 24                        {'programming': ['python']}                 6
# 25                           {'programming': ['sql']}                 6
# 33  {'cloud': ['azure', 'databricks'], 'libraries'...                 6
# 51  {'cloud': ['aws', 'databricks'], 'libraries': ...                 6
# 65  {'libraries': ['hadoop', 'spark'], 'other': ['...                 6
# 70  {'cloud': ['oracle'], 'libraries': ['scikit-le...                 6
# 73  {'analyst_tools': ['word', 'excel', 'powerpoin...                 6
# 77  {'analyst_tools': ['tableau'], 'cloud': ['orac...                 6
# 93  {'analyst_tools': ['power bi', 'excel', 'word'...                 6
# 96  {'analyst_tools': ['sap'], 'cloud': ['azure', ...                 6

# %% [markdown]
# ---
